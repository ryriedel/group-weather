# %% [markdown]
# # Team C3
# <br> **Group members:**
# - Chad Pranke
# - Eric Choi
# - Jenny Theresia

# %% [markdown]
# ## Datasets
#
# The following datasets consist of historical hourly temperature data between 2012 and 2017 for 30 US & Canadian Cities and 6 Israeli Cities. We hope to analyze the temperature changes in these cities over the years.
#
# <br> **Source:**
#
# The data was obtained from https://www.kaggle.com/selfishgene/historical-hourly-weather-data#wind_speed.csv. The author states the original input data was aquired by using Weather API on the OpenWeatherMap website, and is available under the ODbL License.

# %%
import numpy as np 
import pandas as pd

# %%
filename = 'temperature.csv'

# %%
f = open(filename,'r')

# %%
reader = pd.read_csv(f,",")

# %%
reader
# Out:
#                   datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0      2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1      2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2      2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3      2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4      2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
# 5      2012-10-01 17:00:00  284.622911  282.109095     289.431869  281.775065
# 6      2012-10-01 18:00:00  284.620868  282.117710     289.417494  281.767681
# 7      2012-10-01 19:00:00  284.618824  282.126324     289.403119  281.760297
# 8      2012-10-01 20:00:00  284.616781  282.134939     289.388745  281.752912
# 9      2012-10-01 21:00:00  284.614738  282.143553     289.374370  281.745528
# 10     2012-10-01 22:00:00  284.612694  282.152168     289.359995  281.738144
# ...
